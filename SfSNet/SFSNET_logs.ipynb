# %%
# !pip install imutils
# !pip install PyDrive
# !pip install pydrive --upgrade
# Out:
# Collecting imutils
#   Downloading https://files.pythonhosted.org/packages/ee/29/6b20a2f2444be479cbd74b8fb0dd2ee92671e1c52360f1cb022c6c00e052/imutils-0.5.1.tar.gz
# Building wheels for collected packages: imutils
# done
#   Stored in directory: /root/.cache/pip/wheels/4c/ff/aa/824fb9efc5b8c740d54cd8bc19c7e85fbb8d115c77e56812c7
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.1
# Collecting PyDrive
#   Downloading https://files.pythonhosted.org/packages/52/e0/0e64788e5dd58ce2d6934549676243dc69d982f198524be9b99e9c2a4fd5/PyDrive-1.3.1.tar.gz (987kB)
#     100% |████████████████████████████████| 993kB 17.0MB/s
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (1.6.7)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (4.1.2)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.11.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.0)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.11.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (3.4.2)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.2.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.4)
# Building wheels for collected packages: PyDrive
# done
#   Stored in directory: /root/.cache/pip/wheels/fa/d2/9a/d3b6b506c2da98289e5d417215ce34b696db856643bad779f4
# Successfully built PyDrive
# Installing collected packages: PyDrive
# Successfully installed PyDrive-1.3.1
# Requirement already up-to-date: pydrive in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied, skipping upgrade: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pydrive) (4.1.2)
# Requirement already satisfied, skipping upgrade: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from pydrive) (3.13)
# Requirement already satisfied, skipping upgrade: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from pydrive) (1.6.7)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive) (0.4.4)
# Requirement already satisfied, skipping upgrade: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive) (3.4.2)
# Requirement already satisfied, skipping upgrade: six>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive) (1.11.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive) (0.2.2)
# Requirement already satisfied, skipping upgrade: httplib2>=0.9.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive) (0.11.3)
# Requirement already satisfied, skipping upgrade: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->pydrive) (3.0.0)

# %% [markdown]
# ###  Initialization

# %%
import numpy as np
import math as m
import h5py
import matplotlib
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
import os
import imutils
import skimage
from skimage import io
from skimage import transform
from matplotlib import pyplot as plt


from google.colab import auth
from oauth2client.client import GoogleCredentials
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

# %% [markdown]
# ### Mounting google drive with this Colab Notebook

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# Preconfiguring packages ...
# Selecting previously unselected package cron.
# (Reading database ... 18408 files and directories currently installed.)
# Preparing to unpack .../00-cron_3.0pl1-128ubuntu5_amd64.deb ...
# Unpacking cron (3.0pl1-128ubuntu5) ...
# Selecting previously unselected package libapparmor1:amd64.
# Preparing to unpack .../01-libapparmor1_2.11.0-2ubuntu17.1_amd64.deb ...
# Unpacking libapparmor1:amd64 (2.11.0-2ubuntu17.1) ...
# Selecting previously unselected package libdbus-1-3:amd64.
# Preparing to unpack .../02-libdbus-1-3_1.10.22-1ubuntu1_amd64.deb ...
# Unpacking libdbus-1-3:amd64 (1.10.22-1ubuntu1) ...
# Selecting previously unselected package dbus.
# Preparing to unpack .../03-dbus_1.10.22-1ubuntu1_amd64.deb ...
# Unpacking dbus (1.10.22-1ubuntu1) ...
# Selecting previously unselected package dirmngr.
# Preparing to unpack .../04-dirmngr_2.1.15-1ubuntu8.1_amd64.deb ...
# Unpacking dirmngr (2.1.15-1ubuntu8.1) ...
# Selecting previously unselected package distro-info-data.
# Preparing to unpack .../05-distro-info-data_0.36ubuntu0.2_all.deb ...
# Unpacking distro-info-data (0.36ubuntu0.2) ...
# Selecting previously unselected package libkmod2:amd64.
# Preparing to unpack .../06-libkmod2_24-1ubuntu2_amd64.deb ...
# Unpacking libkmod2:amd64 (24-1ubuntu2) ...
# Selecting previously unselected package kmod.
# Preparing to unpack .../07-kmod_24-1ubuntu2_amd64.deb ...
# Unpacking kmod (24-1ubuntu2) ...
# Selecting previously unselected package lsb-release.
# Preparing to unpack .../08-lsb-release_9.20160110ubuntu5_all.deb ...
# Unpacking lsb-release (9.20160110ubuntu5) ...
# Selecting previously unselected package libgirepository-1.0-1:amd64.
# Preparing to unpack .../09-libgirepository-1.0-1_1.54.1-1_amd64.deb ...
# Unpacking libgirepository-1.0-1:amd64 (1.54.1-1) ...
# Selecting previously unselected package gir1.2-glib-2.0:amd64.
# Preparing to unpack .../10-gir1.2-glib-2.0_1.54.1-1_amd64.deb ...
# Unpacking gir1.2-glib-2.0:amd64 (1.54.1-1) ...
# Selecting previously unselected package iso-codes.
# Preparing to unpack .../11-iso-codes_3.75-1_all.deb ...
# Unpacking iso-codes (3.75-1) ...
# Selecting previously unselected package libdbus-glib-1-2:amd64.
# Preparing to unpack .../12-libdbus-glib-1-2_0.108-2_amd64.deb ...
# Unpacking libdbus-glib-1-2:amd64 (0.108-2) ...
# Selecting previously unselected package python-apt-common.
# Preparing to unpack .../13-python-apt-common_1.4.0~beta3build2_all.deb ...
# Unpacking python-apt-common (1.4.0~beta3build2) ...
# Selecting previously unselected package python3-apt.
# Preparing to unpack .../14-python3-apt_1.4.0~beta3build2_amd64.deb ...
# Unpacking python3-apt (1.4.0~beta3build2) ...
# Selecting previously unselected package python3-dbus.
# Preparing to unpack .../15-python3-dbus_1.2.4-1build3_amd64.deb ...
# Unpacking python3-dbus (1.2.4-1build3) ...
# Selecting previously unselected package python3-gi.
# Preparing to unpack .../16-python3-gi_3.24.1-2build1_amd64.deb ...
# Unpacking python3-gi (3.24.1-2build1) ...
# Selecting previously unselected package module-init-tools.
# Preparing to unpack .../17-module-init-tools_24-1ubuntu2_all.deb ...
# Unpacking module-init-tools (24-1ubuntu2) ...
# Selecting previously unselected package python-apt.
# Preparing to unpack .../18-python-apt_1.4.0~beta3build2_amd64.deb ...
# Unpacking python-apt (1.4.0~beta3build2) ...
# Selecting previously unselected package python-pycurl.
# Preparing to unpack .../19-python-pycurl_7.43.0-2build2_amd64.deb ...
# Unpacking python-pycurl (7.43.0-2build2) ...
# Selecting previously unselected package python-software-properties.
# Preparing to unpack .../20-python-software-properties_0.96.24.17_all.deb ...
# Unpacking python-software-properties (0.96.24.17) ...
# Selecting previously unselected package python3-software-properties.
# Preparing to unpack .../21-python3-software-properties_0.96.24.17_all.deb ...
# Unpacking python3-software-properties (0.96.24.17) ...
# Selecting previously unselected package software-properties-common.
# Preparing to unpack .../22-software-properties-common_0.96.24.17_all.deb ...
# Unpacking software-properties-common (0.96.24.17) ...
# Selecting previously unselected package unattended-upgrades.
# Preparing to unpack .../23-unattended-upgrades_0.98ubuntu1.1_all.deb ...
# Unpacking unattended-upgrades (0.98ubuntu1.1) ...
# Setting up python-apt-common (1.4.0~beta3build2) ...
# Setting up python3-apt (1.4.0~beta3build2) ...
# Setting up iso-codes (3.75-1) ...
# Setting up distro-info-data (0.36ubuntu0.2) ...
# Setting up python-pycurl (7.43.0-2build2) ...
# Setting up lsb-release (9.20160110ubuntu5) ...
# Setting up libgirepository-1.0-1:amd64 (1.54.1-1) ...
# Setting up libkmod2:amd64 (24-1ubuntu2) ...
# Setting up gir1.2-glib-2.0:amd64 (1.54.1-1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up libapparmor1:amd64 (2.11.0-2ubuntu17.1) ...
# Setting up unattended-upgrades (0.98ubuntu1.1) ...
#
# Creating config file /etc/apt/apt.conf.d/20auto-upgrades with new version
#
# Creating config file /etc/apt/apt.conf.d/50unattended-upgrades with new version
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up dirmngr (2.1.15-1ubuntu8.1) ...
# Setting up cron (3.0pl1-128ubuntu5) ...
# Adding group `crontab' (GID 102) ...
# Done.
# update-rc.d: warning: start and stop actions are no longer supported; falling back to defaults
# update-rc.d: warning: stop runlevel arguments (1) do not match cron Default-Stop values (none)
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libdbus-1-3:amd64 (1.10.22-1ubuntu1) ...
# Setting up kmod (24-1ubuntu2) ...
# Setting up libdbus-glib-1-2:amd64 (0.108-2) ...
# Setting up python3-gi (3.24.1-2build1) ...
# Setting up module-init-tools (24-1ubuntu2) ...
# Setting up python3-software-properties (0.96.24.17) ...
# Setting up dbus (1.10.22-1ubuntu1) ...
# Setting up python-apt (1.4.0~beta3build2) ...
# Setting up python3-dbus (1.2.4-1build3) ...
# Setting up python-software-properties (0.96.24.17) ...
# Setting up software-properties-common (0.96.24.17) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Processing triggers for dbus (1.10.22-1ubuntu1) ...
# gpg: keybox '/tmp/tmptjrt95cg/pubring.gpg' created
# gpg: /tmp/tmptjrt95cg/trustdb.gpg: trustdb created
# gpg: key AD5F235DF639B041: public key "Launchpad PPA for Alessandro Strada" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Warning: apt-key output should not be parsed (stdout is not a terminal)
# Selecting previously unselected package libfuse2:amd64.
# (Reading database ... 19816 files and directories currently installed.)
# Preparing to unpack .../libfuse2_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Selecting previously unselected package fuse.
# Preparing to unpack .../fuse_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking fuse (2.9.7-1ubuntu1) ...
# Selecting previously unselected package google-drive-ocamlfuse.
# Preparing to unpack .../google-drive-ocamlfuse_0.6.21-0ubuntu2_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.6.21-0ubuntu2) ...
# Setting up libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up fuse (2.9.7-1ubuntu1) ...
# Setting up google-drive-ocamlfuse (0.6.21-0ubuntu2) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
# !ls
#Code to download CelebA hdf5 dataset from google drive
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

fileId = drive.CreateFile({'id': '1D7MYVPbn4JSVRZMQbQogfW2anmXLCKY7'})

print(fileId['title'])  # CelebA Dataset
fileId.GetContentFile('Syn_data_medium.zip')  # Save Drive file as a local file
# Out:
# adc.json  drive  sample_data
# Syn_data_medium.zip

# %%
# Unzip synthetic data
import zipfile
zip_ref = zipfile.ZipFile('Syn_data_medium.zip', 'r')
zip_ref.extractall('SyntheticData')
zip_ref.close()

# %%
# !ls 
# !ls sample_data/
# Out:
# adc.json  drive  sample_data  Syn_data_medium.zip  SyntheticData
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
image_list = []
normal_list = []
albedo_list = []
mask = []
light = []
cwd = os.getcwd()

# generating list for image, albedo, normal, lighting SH and mask in a similar order
for i in range(0,10):
    folder = str(i+1).zfill(4)
    print(folder)
    path = cwd + '/SyntheticData/data/' + folder + '/'
    #print(path)
    addrs = os.walk(path)
    for root, dirs, filename in addrs:
        filename.sort() 
        for file in filename:
            if (file.endswith(".png") and 'face' in file):
                im=io.imread(os.path.join(root, file))
                image_list.append(skimage.transform.resize(im,(128,128)))           
            elif (file.endswith(".png") and 'albedo' in file):
                im=io.imread(os.path.join(root, file))
                albedo_list.append(skimage.transform.resize(im,(128,128)))   
            elif (file.endswith(".png") and 'normal' in file):
                im=io.imread(os.path.join(root, file))
                normal_list.append(skimage.transform.resize(im,(128,128)))
            elif (file.endswith(".png") and 'mask' in file):
                im=io.imread(os.path.join(root, file))
                mask.append(skimage.transform.resize(im,(128,128)))           
            elif (file.endswith(".txt")):
                text = open(os.path.join(root, file),"r") 
                data = text.read()
                data = data.split()
                light.append(data)         

#print(len(image_list))
# converting list to array 
image_list = np.array(image_list)
albedo_list = np.array(albedo_list)
normal_list = np.array(normal_list)
light = np.array(light)
mask = np.array(mask)
# Out:
# 0001
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 0002
# 0003
# 0004
# 0005
# 0006
# 0007
# 0008
# 0009
# 0010

# %%
# converting to flot32 type array
image_list = np.asarray(image_list).astype(np.float32)
normal_list = np.asarray(normal_list).astype(np.float32)
albedo_list = np.asarray(albedo_list).astype(np.float32)
light = np.asarray(light).astype(np.float32)
mask = np.asarray(mask).astype(np.float32)

# %%
print(image_list.shape)
print(albedo_list.shape)
print(normal_list.shape)
print(light.shape)
print(mask.shape)
# Out:
# (3000, 128, 128, 3)
# (3000, 128, 128, 3)
# (3000, 128, 128, 3)
# (3000, 27)
# (3000, 128, 128, 3)

# %%
# plotting image, albedo, normal and mask for one face from synthetic dataset 
fig, axs = plt.subplots(1,4,figsize=(15,5))

img = image_list[5]
axs[0].imshow(img)
axs[0].axis('off')
axs[0].set_title('Image')

img = albedo_list[5]
axs[1].imshow(img)
axs[1].axis('off')
axs[1].set_title('Albedo')

img = normal_list[5]
axs[2].imshow(img)
axs[2].axis('off')
axs[2].set_title('Normal')

img = mask[5]
axs[3].imshow(img)
axs[3].axis('off')
axs[3].set_title('Mask')
# Out:
# Text(0.5,1,'Mask')

# %%
normal_label=np.asarray([1 for i in range(normal_list.shape[0])])
albedo_label=np.asarray([1 for i in range(albedo_list.shape[0])])
mask_label=np.asarray([1 for i in range(mask.shape[0])])

# %%
n_total = image_list.shape[0]
train_min_index = int(n_total * 0)
train_max_index = int(n_total * 0.8)
test_min_index = int((n_total * 0.8))
test_max_index = int(n_total * 1)

train_data = {"images": image_list[:train_max_index], "normals": normal_list[:train_max_index], "albedos": albedo_list[:train_max_index],\
              "lightings": light[:train_max_index], "mask": mask[:train_max_index], "nlabel": normal_label[:train_max_index],\
              "alabel": albedo_label[:train_max_index], "mlabel": mask_label[:train_max_index]}

test_data = {"images": image_list[test_min_index:], "normals": normal_list[test_min_index:], "albedos": albedo_list[test_min_index:],\
             "lightings": light[test_min_index:], "mask": mask[test_min_index:], "nlabel": normal_label[test_min_index:],\
             "alabel": albedo_label[test_min_index:], "mlabel": mask_label[test_min_index:]}

# %%
print(train_data["images"].shape)
print(test_data["images"].shape)
# Out:
# (2400, 128, 128, 3)
# (600, 128, 128, 3)

# %%
def input_fn(data):
    # Input function for tf.estimator
    '''      
        Input: train, validation or test data
        
        Output: features and labels as dictionary
    '''
    
    features = {"images":data['images'],"mask":data['mask']}
    labels = {"normals":data['normals'], "albedos":data['albedos'], "lightings":data['lightings'],
              "nlabel":data['nlabel'], "alabel":data['alabel'], "mlabel":data['mlabel']}
    
    return features, labels

# %%
def model_fn(features, labels, mode, params):
    # The network architecture along with loss functions 
    '''
        Input: Features(i.e. images and corresponding masks)
               Labels(i.e. Normal, Albedo, lighting and their labels)
               Mode(one of tf.estimator.ModeKeys.{TRAIN, PREDICT, EVAL})
               Parameters(A dictionary containing all the hyperparameters for the training
               
        Output:ModelFnOps for Estimator API.
    '''
    def NormLayer(bottom_layer):
        # Normalisation layer(Helper Method)

        sz=bottom_layer.shape
        nor=bottom_layer
        nor=2*nor-1

        ssq=tf.norm(nor,axis=3, keepdims=True)
        norm=tf.tile(ssq,[1,1,1,sz[3]]) + 1e-8
        top_layer=tf.divide(nor,norm)

        return top_layer
    
    def ShadingLayer(normal_output, light_output):
        # Shading Layer(Helper Method)
        top = tf.zeros_like(normal_output)
        #top = np.zeros(bottom1.shape)
        sz = normal_output.shape
        att = np.pi*np.array([1, 2.0/3, 0.25])

        c1=att[0]*(1.0/np.sqrt(4*np.pi))
        c2=att[1]*(np.sqrt(3.0/(4*np.pi)))
        c3=att[2]*0.5*(np.sqrt(5.0/(4*np.pi)))
        c4=att[2]*(3.0*(np.sqrt(5.0/(12*np.pi))))
        c5=att[2]*(3.0*(np.sqrt(5.0/(48*np.pi))))
        
        shading_img_batch = []  # Empty list for storing all the shading images of the batch
        for i in range(params.batch_size):
            nx = normal_output[i,:,:,0]
            ny = normal_output[i,:,:,1]
            nz = normal_output[i,:,:,2]
          
            H1 = c1*tf.ones([sz[1],sz[2]])
            H2 = c2*nz
            H3 = c2*nx
            H4 = c2*ny
            H5 = c3*(2*nz*nz - nx*nx -ny*ny)
            H6 = c4*nx*nz
            H7 = c4*ny*nz
            H8 = c5*(nx*nx - ny*ny)
            H9 = c4*nx*ny
          
            shading_img = []
            for j in range(0,3):
                L = light_output[i,j*9:(j+1)*9]
                shading_output = L[0]*H1+L[1]*H2+L[2]*H3+L[3]*H4+L[4]*H5+L[5]*H6+L[6]*H7+L[7]*H8+L[8]*H9
                shading_img.append(shading_output)
            #print(len(shading_img))
            shading_img = tf.stack(shading_img, axis=0)
            #print(shading_img.shape)
            shading_img = tf.transpose(shading_img, [1,2,0])
            #print(shading_img.shape)
            shading_img_batch.append(shading_img)
          
        shading_img_batch = tf.stack(shading_img_batch, axis=0)
        #print(shading_img_batch.shape)
        
        return shading_img_batch
  
    # Initialisation for training
    image = features["images"]
    mask = features["mask"]
    albedo = None
    normal = None
    light = None
    nlabel = None
    alabel = None
    mlabel = None
    if mode != tf.estimator.ModeKeys.PREDICT:
      albedo = labels['albedos']
      normal = labels['normals']
      light = labels['lightings']
      nlabel = labels['nlabel']
      alabel = labels['alabel']
      mlabel = labels['mlabel']


    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    
    conv1 = tf.layers.conv2d(inputs=image, filters=64, kernel_size=7, strides=1, padding="SAME", activation=tf.nn.relu,
                     kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name="conv1")

    conv1 =tf.layers.batch_normalization(inputs=conv1, training=is_training, name="bn1")

    conv2 = tf.layers.conv2d(inputs=conv1, filters=128, kernel_size=3, strides=1, padding="SAME", activation=tf.nn.relu, 
                     kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name = "conv2")

    conv2 =tf.layers.batch_normalization(inputs=conv2, training=is_training, name="bn2")

    conv3 = tf.layers.conv2d(inputs=conv1, filters=128, kernel_size=3, strides=2, padding="SAME", activation=None, 
                     kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name="conv3")

	#########################################################################################################

    # Normal Residual block 

    #nconv = tf.get_variable(dtype=float, size=6,name="nconv")
    #nconv = tf.zeros_like(nconv, dtype='float64')
    nconv = []
    #nconvr = tf.get_variable("nconvr", [6])
    #nconvr = tf.zeros_like(nconvr, dtype='float64')
    nconvr = []
    #nsum = tf.get_variable("nsum", [6])
    #nsum = tf.zeros_like(nsum, dtype='float64')
    nsum = []
    #nbn = tf.get_variable("nbn", [6])
    #nbn = tf.zeros_like(nbn, dtype='float64')
    nbn = []
    conv3_n = tf.nn.relu(conv3, name="nrelu1")
    nbn_iter = tf.layers.batch_normalization(inputs=conv3_n, training=is_training, name="nbn1")


    nconv_iter = tf.layers.conv2d(inputs=nbn_iter, filters=128, kernel_size=3, strides=1, padding="SAME", activation=tf.nn.relu, 
                     kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name = "nconv1")

    nconv_iter =tf.layers.batch_normalization(inputs=nconv_iter, training=is_training, name="nbn1r")

    nconvr_iter = tf.layers.conv2d(inputs=nconv_iter, filters=128, kernel_size=3, strides=1, padding="SAME", activation=None, 
                     kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name = "nconv1r")

    nsum_iter = tf.add(conv3_n, nconvr_iter, name="nsum1" )
    
    nbn.append(nbn_iter)
    nconv.append(nconv_iter)
    nconvr.append(nconvr_iter)
    nsum.append(nsum_iter)
    for i in range(2, 5):

        nsum[-1] = tf.nn.relu(nsum[-1], name="nrelu"+str(i))
        nbn_iter = tf.layers.batch_normalization(inputs=nsum[-1], training=is_training, name="nbn"+str(i))


        nconv_iter = tf.layers.conv2d(inputs=nbn_iter, filters=128, kernel_size=3, strides=1, padding="SAME", activation=tf.nn.relu, 
                        kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name="nconv"+str(i))

        nconv_iter =tf.layers.batch_normalization(inputs=nconv_iter, training=is_training, name="nbn"+str(i)+"r")

        nconvr_iter = tf.layers.conv2d(inputs=nconv_iter, filters=128, kernel_size=3, strides=1, padding="SAME", activation=None, 
                        kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name="nconv"+str(i)+"r")

        nsum_iter = tf.add(nconvr_iter, nsum[-1], name="nsum"+str(i))
        
        nbn.append(nbn_iter)
        nconv.append(nconv_iter)
        nconvr.append(nconvr_iter)
        nsum.append(nsum_iter)
        
        
    nsum[-1] = tf.nn.relu(nsum[-1], name="nrelu6r")
    nsum[-1] = tf.layers.batch_normalization(inputs=nsum[-1], training=is_training, name="nbn6r")

    # Normal Deconvolutional Block 
    
    # Unable to implement bilinear upsampling(as kernel initializer)
    nup6 = tf.layers.conv2d_transpose(inputs=nsum[-1], filters=128,  kernel_size=4, strides=2, padding="SAME", use_bias=False, name="nup6")

    nconv6 = tf.layers.conv2d(inputs=nup6, filters=128, kernel_size=1, strides=1, padding="VALID", activation=tf.nn.relu, 
                        kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name = "nconv6")

    nconv6 = tf.layers.batch_normalization(inputs=nconv6, training=is_training, name="nbn6")

    nconv7 = tf.layers.conv2d(inputs=nconv6, filters=64, kernel_size=3, strides=1, padding="SAME", activation=tf.nn.relu, 
                        kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name="nconv7")

    nconv7 = tf.layers.batch_normalization(inputs=nconv7, training=is_training, name="nbn7")


    Nconv0 = tf.layers.conv2d(inputs=nconv7, filters=3, kernel_size=1, strides=1, padding="VALID", activation=tf.nn.relu, 
                        kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name="Nconv0")



    #########################################################################################################

    # Albedo Residual block
    #aconv = tf.get_variable("aconv",[6])
    #aconv = tf.zeros_like(aconv, dtype='float64')
    aconv = []
    #aconvr = tf.get_variable("aconvr",[6])
    #aconvr = tf.zeros_like(aconvr, dtype='float64')
    aconvr = []
    #asum = tf.get_variable("asum",[6])
    #asum = tf.zeros_like(asum, dtype='float64')
    asum = []
    #abn = tf.get_variable("abn",[6])
    #abn = tf.zeros_like(abn, dtype='float64')
    abn = []
    
    
    conv3_a = tf.nn.relu(conv3, name="arelu1")
    abn_iter = tf.layers.batch_normalization(inputs=conv3_a, training=is_training, name="abn1")


    aconv_iter = tf.layers.conv2d(inputs=abn_iter, filters=128, kernel_size=3, strides=1, padding="SAME", activation=tf.nn.relu, 
                     kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name = "aconv1")

    aconv_iter =tf.layers.batch_normalization(inputs=aconv_iter, training=is_training, name="abn1r")

    aconvr_iter = tf.layers.conv2d(inputs=aconv_iter, filters=128, kernel_size=3, strides=1, padding="SAME", activation=None, 
                     kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name = "aconv1r")

    asum_iter = tf.add(conv3_a, aconvr_iter, name="asum1" )
    
    abn.append(abn_iter)
    aconv.append(aconv_iter)
    aconvr.append(aconvr_iter)
    asum.append(asum_iter)


    for i in range(2, 5):

        asum[-1] = tf.nn.relu(asum[-1], name="arelu"+str(i))
        abn_iter = tf.layers.batch_normalization(inputs=asum[-1], training=is_training, name="abn"+str(i))


        aconv_iter = tf.layers.conv2d(inputs=abn_iter, filters=128, kernel_size=3, strides=1, padding="SAME", activation=tf.nn.relu, 
                        kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name = "aconv"+str(i))

        aconv_iter =tf.layers.batch_normalization(inputs=aconv_iter, training=is_training, name="abn"+str(i)+"r")

        aconvr_iter = tf.layers.conv2d(inputs=aconv_iter, filters=128, kernel_size=3, strides=1, padding="SAME", activation=None, 
                        kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name = "aconv"+str(i)+"r")

        asum_iter = tf.add(aconvr_iter, asum[-1], name="asum"+str(i))
        
        abn.append(abn_iter)
        aconv.append(aconv_iter)
        aconvr.append(aconvr_iter)
        asum.append(asum_iter)        

    asum[-1] = tf.nn.relu(asum[-1], name="arelu6r")
    asum[-1] = tf.layers.batch_normalization(inputs=asum[-1], training=is_training, name="abn6r")

    # Albedo Deconvolutional Block 

    aup6 = tf.layers.conv2d_transpose(inputs=asum[-1], filters=128,  kernel_size=4, strides=2, padding="SAME", use_bias=False, name="aup6")

    aconv6 = tf.layers.conv2d(inputs=aup6, filters=128, kernel_size=1, strides=1, padding="VALID", activation=tf.nn.relu, 
                        kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name = "aconv6")

    aconv6 = tf.layers.batch_normalization(inputs=aconv6, training=is_training, name="abn6")

    aconv7 = tf.layers.conv2d(inputs=aconv6, filters=64, kernel_size=3, strides=1, padding="SAME", activation=tf.nn.relu, 
                        kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name="aconv7")

    aconv7 = tf.layers.batch_normalization(inputs=aconv7, training=is_training, name="abn7")


    Aconv0 = tf.layers.conv2d(inputs=aconv7, filters=3, kernel_size=1, strides=1, padding="VALID", activation=tf.nn.relu, 
                        kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name="Aconv0")


    #########################################################################################################

    # Light Estimation Block

    lconcat1 = tf.concat([nsum[-1], asum[-1]], axis=3, name="lconcat1")
    lconcat2 = tf.concat([lconcat1, conv3], axis=3, name="lconcat2")
    lconv1 = tf.layers.conv2d(inputs=lconcat2, filters=128, kernel_size=1, strides=1, padding="VALID", activation=tf.nn.relu, 
                        kernel_initializer=tf.contrib.layers.xavier_initializer(), trainable=is_training, name="lconv1")

    lconv1 = tf.layers.batch_normalization(inputs=lconv1, training=is_training, name="lbn1")
 
    lpool2r = tf.layers.average_pooling2d(inputs=lconv1, pool_size=64, strides=1, padding="VALID", name="lpool2r")
    
    # Additional flatten layer as compared to Caffe to convert it into a single dimensional vector so that dense operation can be run on it.
    lflat2r = tf.layers.flatten(inputs=lpool2r, name="lflat2r")

    # TODO: How to set std value for the kernel_initializer in the dense layer itself. 
    fc_light = tf.layers.dense(inputs=lflat2r, units=27, kernel_initializer=tf.truncated_normal_initializer(), bias_initializer=tf.ones_initializer(), trainable=is_training, name="fc_light")
    
    #########################################################################################################
    # Applying masks and other functions for loss calculations

    #print("Before norm layer")
    recnormal = NormLayer(Nconv0)
    #print("Post norm layer")
    if mode != tf.estimator.ModeKeys.PREDICT:
        normal_m = tf.multiply(labels['normals'], features['mask'], name="mask_norgt")
        albedo_m = tf.multiply(labels['albedos'], features['mask'], name="mask_algt")
    
    arec = tf.multiply(Aconv0, features['mask'], name="mask_al")
    rec = tf.multiply(Nconv0, features['mask'], name="mask_nor")
    
    shading_without_mask = ShadingLayer(recnormal, fc_light)
    #print(Aconv0.shape, shading.shape)
    shading = tf.multiply(shading_without_mask, features['mask'], name="mask_shading")
    recon = tf.multiply(Aconv0, shading, name="recon")
    recon_mask = tf.multiply(features['mask'], recon, name="mask_recon")
    data_mask = tf.multiply(features['mask'], features['images'], name="mask_data")
    
    #########################################################################################################
    
    # Return the estimator if in PREDICT mode
    
    if mode == tf.estimator.ModeKeys.PREDICT :
        
        predicted_estimator = tf.estimator.EstimatorSpec(mode=mode, predictions={'normal':rec, 'albedo':arec, \
                                                                                 'light':fc_light, 'recon':recon_mask, 'shading': shading})
    
    else:
        
        def l1_loss_layer_wt(input1, input2, input3, param_str):
            # Custom L1 Loss function
            
            if (input3 == 1):
                wt = param_str['wt_real']
            else:
                wt = param_str['wt_syn']
            
            l1_loss = tf.reduce_mean(tf.scalar_mul(wt, tf.losses.absolute_difference(input1, input2)))

            return l1_loss

        def l2_loss_layer_wt(input1, input2, input3, param_str):
            # Custom L2 Loss function
            #print(param_str)
            if input3 == 1:
                wt = param_str['wt_real']
            else:
                wt = param_str['wt_syn']
                	
            
            l2_loss = tf.reduce_mean(tf.scalar_mul(wt, tf.losses.mean_squared_error(input1, input2)))

            return l2_loss
        
        params={'wt_real':0.5, 'wt_syn':0.5}    # MODIFY LATER

        # L2 loss for the lighting coefficients.
        lloss = l2_loss_layer_wt(fc_light, light, labels['mlabel'], params)

        # L1 loss for albedo, normal and reconstruction.

        aloss = l1_loss_layer_wt(arec, albedo_m, labels['alabel'], params)
        reconloss = l1_loss_layer_wt(recon_mask, data_mask, labels['mlabel'], params)
        loss = l1_loss_layer_wt(rec, normal_m, labels['nlabel'], params)   
        
        final_loss = tf.reduce_mean(0.5*lloss + 0.5*aloss + 0.5*reconloss + 0.1*loss)


        # Adding optimizer
        train_op = tf.contrib.layers.optimize_loss(loss=final_loss, global_step=tf.train.get_global_step(), \
                                                   learning_rate=0.000005, optimizer="Adam")
        
        predicted_estimator = tf.estimator.EstimatorSpec(mode=mode, predictions={'normal':rec, 'albedo':arec, 'light':fc_light, \
                                                         'recon':recon_mask, 'shading': shading}, loss=final_loss, train_op=train_op,\
                                                         eval_metric_ops={'normal_loss':tf.metrics.mean_absolute_error(rec, normal_m),\
                                                                          'albedo_loss':tf.metrics.mean_absolute_error(arec, albedo_m),\
                                                                          'lighting_loss':tf.metrics.mean_squared_error(fc_light, light),\
                                                                          'reconstruction_loss':tf.metrics.mean_absolute_error(recon_mask, data_mask)})
        
    return predicted_estimator

# %%
def create_estimator_and_specs(run_config):
    # Creates a trial configuration based on the estimator and input fn.
    model_params = tf.contrib.training.HParams(batch_size = 10, learning_rate = 0.000005)

    estimator = tf.estimator.Estimator(model_fn=model_fn, config=run_config, params=model_params)
  
    train_features, train_labels = input_fn(train_data)
    test_features, test_labels = input_fn(test_data)
    #print(train_features['images'].shape)
    train_input_fn = tf.estimator.inputs.numpy_input_fn(x=train_features, y=train_labels,
                                                        num_epochs=500000, batch_size=10, shuffle=True)
  
    eval_input_fn = tf.estimator.inputs.numpy_input_fn(x=test_features, y=test_labels,
                                                       num_epochs=10000, batch_size=10, shuffle=True)
  
    train_spec = tf.estimator.TrainSpec(train_input_fn, max_steps=500000)
  
    eval_spec = tf.estimator.EvalSpec(eval_input_fn, steps=100, name='validation', start_delay_secs=150, throttle_secs=500)

    return estimator, train_spec, eval_spec

# %%
estimator, train_spec, eval_spec = create_estimator_and_specs(run_config=tf.estimator.RunConfig(
                                                              model_dir="./drive/Colab Notebooks/SFSNet/",
                                                              save_checkpoints_steps=1000,
                                                              save_summary_steps=5000))
tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': './drive/Colab Notebooks/SFSNet/', '_tf_random_seed': None, '_save_summary_steps': 5000, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f016b48d438>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1000 or save_checkpoints_secs None.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-30000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 30000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:loss = 0.016052524, step = 30000
# INFO:tensorflow:global_step/sec: 1.34233
# INFO:tensorflow:loss = 0.015154101, step = 30100 (76.039 sec)
# INFO:tensorflow:global_step/sec: 1.49394
# INFO:tensorflow:loss = 0.015613498, step = 30200 (65.397 sec)
# INFO:tensorflow:global_step/sec: 1.53343
# INFO:tensorflow:loss = 0.012896469, step = 30300 (66.404 sec)
# INFO:tensorflow:global_step/sec: 1.50583
# INFO:tensorflow:loss = 0.018796207, step = 30400 (65.218 sec)
# INFO:tensorflow:global_step/sec: 1.53189
# INFO:tensorflow:loss = 0.017823301, step = 30500 (66.140 sec)
# INFO:tensorflow:global_step/sec: 1.51336
# INFO:tensorflow:loss = 0.015090029, step = 30600 (65.217 sec)
# INFO:tensorflow:global_step/sec: 1.53472
# INFO:tensorflow:loss = 0.015168432, step = 30700 (66.008 sec)
# INFO:tensorflow:global_step/sec: 1.5132
# INFO:tensorflow:loss = 0.01909812, step = 30800 (65.236 sec)
# INFO:tensorflow:global_step/sec: 1.53248
# INFO:tensorflow:loss = 0.017336804, step = 30900 (66.427 sec)
# INFO:tensorflow:Saving checkpoints for 31000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-20:22:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-31000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-20:22:32
# INFO:tensorflow:Saving dict for global step 31000: albedo_loss = 0.026809089, global_step = 31000, lighting_loss = 0.008776138, loss = 0.016836433, normal_loss = 0.049196523, reconstruction_loss = 0.021921214
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 31000: ./drive/Colab Notebooks/SFSNet/model.ckpt-31000
# INFO:tensorflow:global_step/sec: 0.71125
# INFO:tensorflow:loss = 0.014819787, step = 31000 (139.449 sec)
# INFO:tensorflow:global_step/sec: 1.53524
# INFO:tensorflow:loss = 0.01643987, step = 31100 (65.111 sec)
# INFO:tensorflow:global_step/sec: 1.53326
# INFO:tensorflow:loss = 0.013862245, step = 31200 (66.061 sec)
# INFO:tensorflow:global_step/sec: 1.51371
# INFO:tensorflow:loss = 0.01694236, step = 31300 (65.222 sec)
# INFO:tensorflow:global_step/sec: 1.53367
# INFO:tensorflow:loss = 0.015307501, step = 31400 (66.188 sec)
# INFO:tensorflow:global_step/sec: 1.51053
# INFO:tensorflow:loss = 0.016158806, step = 31500 (65.217 sec)
# INFO:tensorflow:global_step/sec: 1.53645
# INFO:tensorflow:loss = 0.016519047, step = 31600 (65.946 sec)
# INFO:tensorflow:global_step/sec: 1.51424
# INFO:tensorflow:loss = 0.014506422, step = 31700 (65.179 sec)
# INFO:tensorflow:global_step/sec: 1.53639
# INFO:tensorflow:loss = 0.01862528, step = 31800 (66.083 sec)
# INFO:tensorflow:global_step/sec: 1.5115
# INFO:tensorflow:loss = 0.0153579535, step = 31900 (65.164 sec)
# INFO:tensorflow:Saving checkpoints for 32000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-20:34:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-32000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-20:34:51
# INFO:tensorflow:Saving dict for global step 32000: albedo_loss = 0.026318911, global_step = 32000, lighting_loss = 0.008119061, loss = 0.016485509, normal_loss = 0.04793451, reconstruction_loss = 0.021917153
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 32000: ./drive/Colab Notebooks/SFSNet/model.ckpt-32000
# INFO:tensorflow:global_step/sec: 0.694413
# INFO:tensorflow:loss = 0.015165785, step = 32000 (144.006 sec)
# INFO:tensorflow:global_step/sec: 1.5338
# INFO:tensorflow:loss = 0.016675057, step = 32100 (65.198 sec)
# INFO:tensorflow:global_step/sec: 1.53329
# INFO:tensorflow:loss = 0.014979518, step = 32200 (66.041 sec)
# INFO:tensorflow:global_step/sec: 1.5161
# INFO:tensorflow:loss = 0.015289713, step = 32300 (65.137 sec)
# INFO:tensorflow:global_step/sec: 1.53702
# INFO:tensorflow:loss = 0.017689835, step = 32400 (66.393 sec)
# INFO:tensorflow:global_step/sec: 1.50337
# INFO:tensorflow:loss = 0.01561699, step = 32500 (65.185 sec)
# INFO:tensorflow:global_step/sec: 1.53513
# INFO:tensorflow:loss = 0.012982582, step = 32600 (66.065 sec)
# INFO:tensorflow:global_step/sec: 1.51125
# INFO:tensorflow:loss = 0.013198894, step = 32700 (65.247 sec)
# INFO:tensorflow:global_step/sec: 1.53563
# INFO:tensorflow:loss = 0.016342407, step = 32800 (65.998 sec)
# INFO:tensorflow:global_step/sec: 1.516
# INFO:tensorflow:loss = 0.019607944, step = 32900 (65.085 sec)
# INFO:tensorflow:Saving checkpoints for 33000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-20:46:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-33000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-20:46:55
# INFO:tensorflow:Saving dict for global step 33000: albedo_loss = 0.026377156, global_step = 33000, lighting_loss = 0.008327012, loss = 0.016520161, normal_loss = 0.047375076, reconstruction_loss = 0.02190147
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 33000: ./drive/Colab Notebooks/SFSNet/model.ckpt-33000
# INFO:tensorflow:global_step/sec: 0.743761
# INFO:tensorflow:loss = 0.016101025, step = 33000 (134.452 sec)
# INFO:tensorflow:global_step/sec: 1.53496
# INFO:tensorflow:loss = 0.016207892, step = 33100 (65.149 sec)
# INFO:tensorflow:global_step/sec: 1.53759
# INFO:tensorflow:loss = 0.015308803, step = 33200 (66.359 sec)
# INFO:tensorflow:global_step/sec: 1.50499
# INFO:tensorflow:loss = 0.015324878, step = 33300 (65.123 sec)
# INFO:tensorflow:global_step/sec: 1.53359
# INFO:tensorflow:loss = 0.0166408, step = 33400 (66.366 sec)
# INFO:tensorflow:global_step/sec: 1.50744
# INFO:tensorflow:loss = 0.016053485, step = 33500 (65.178 sec)
# INFO:tensorflow:global_step/sec: 1.5333
# INFO:tensorflow:loss = 0.016204162, step = 33600 (66.381 sec)
# INFO:tensorflow:global_step/sec: 1.50934
# INFO:tensorflow:loss = 0.015392354, step = 33700 (65.092 sec)
# INFO:tensorflow:global_step/sec: 1.535
# INFO:tensorflow:loss = 0.016793994, step = 33800 (66.086 sec)
# INFO:tensorflow:global_step/sec: 1.51271
# INFO:tensorflow:loss = 0.013856986, step = 33900 (65.167 sec)
# INFO:tensorflow:Saving checkpoints for 34000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-20:58:39
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-34000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-20:59:03
# INFO:tensorflow:Saving dict for global step 34000: albedo_loss = 0.02635144, global_step = 34000, lighting_loss = 0.008322568, loss = 0.016386412, normal_loss = 0.04703285, reconstruction_loss = 0.02146508
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 34000: ./drive/Colab Notebooks/SFSNet/model.ckpt-34000
# INFO:tensorflow:global_step/sec: 0.732176
# INFO:tensorflow:loss = 0.014079756, step = 34000 (136.579 sec)
# INFO:tensorflow:global_step/sec: 1.5377
# INFO:tensorflow:loss = 0.016808499, step = 34100 (65.032 sec)
# INFO:tensorflow:global_step/sec: 1.53555
# INFO:tensorflow:loss = 0.014881654, step = 34200 (66.073 sec)
# INFO:tensorflow:global_step/sec: 1.51233
# INFO:tensorflow:loss = 0.015736869, step = 34300 (65.173 sec)
# INFO:tensorflow:global_step/sec: 1.53317
# INFO:tensorflow:loss = 0.017642884, step = 34400 (66.089 sec)
# INFO:tensorflow:global_step/sec: 1.51477
# INFO:tensorflow:loss = 0.014808692, step = 34500 (65.153 sec)
# INFO:tensorflow:global_step/sec: 1.53608
# INFO:tensorflow:loss = 0.015120188, step = 34600 (65.927 sec)
# INFO:tensorflow:global_step/sec: 1.51432
# INFO:tensorflow:loss = 0.016543986, step = 34700 (65.210 sec)
# INFO:tensorflow:global_step/sec: 1.53469
# INFO:tensorflow:loss = 0.014733713, step = 34800 (66.165 sec)
# INFO:tensorflow:global_step/sec: 1.51079
# INFO:tensorflow:loss = 0.013766635, step = 34900 (65.186 sec)
# INFO:tensorflow:Saving checkpoints for 35000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-21:10:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-35000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-21:11:09
# INFO:tensorflow:Saving dict for global step 35000: albedo_loss = 0.026220163, global_step = 35000, lighting_loss = 0.008830693, loss = 0.017129395, normal_loss = 0.046978377, reconstruction_loss = 0.024071032
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 35000: ./drive/Colab Notebooks/SFSNet/model.ckpt-35000
# INFO:tensorflow:global_step/sec: 0.735356
# INFO:tensorflow:loss = 0.016709713, step = 35000 (135.990 sec)
# INFO:tensorflow:global_step/sec: 1.53379
# INFO:tensorflow:loss = 0.015815943, step = 35100 (65.197 sec)
# INFO:tensorflow:global_step/sec: 1.53529
# INFO:tensorflow:loss = 0.01621117, step = 35200 (65.987 sec)
# INFO:tensorflow:global_step/sec: 1.51347
# INFO:tensorflow:loss = 0.01623469, step = 35300 (65.221 sec)
# INFO:tensorflow:global_step/sec: 1.53569
# INFO:tensorflow:loss = 0.01877727, step = 35400 (66.090 sec)
# INFO:tensorflow:global_step/sec: 1.51082
# INFO:tensorflow:loss = 0.0137721095, step = 35500 (65.216 sec)
# INFO:tensorflow:global_step/sec: 1.53643
# INFO:tensorflow:loss = 0.01858645, step = 35600 (65.933 sec)
# INFO:tensorflow:global_step/sec: 1.51471
# INFO:tensorflow:loss = 0.014807308, step = 35700 (65.173 sec)
# INFO:tensorflow:global_step/sec: 1.53363
# INFO:tensorflow:loss = 0.015553946, step = 35800 (66.031 sec)
# INFO:tensorflow:global_step/sec: 1.51684
# INFO:tensorflow:loss = 0.014479769, step = 35900 (65.099 sec)
# INFO:tensorflow:Saving checkpoints for 36000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-21:22:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-36000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-21:23:14
# INFO:tensorflow:Saving dict for global step 36000: albedo_loss = 0.025789872, global_step = 36000, lighting_loss = 0.008559401, loss = 0.016626053, normal_loss = 0.04598122, reconstruction_loss = 0.022958692
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 36000: ./drive/Colab Notebooks/SFSNet/model.ckpt-36000
# INFO:tensorflow:global_step/sec: 0.737756
# INFO:tensorflow:loss = 0.015620048, step = 36000 (135.546 sec)
# INFO:tensorflow:global_step/sec: 1.53561
# INFO:tensorflow:loss = 0.016081775, step = 36100 (65.121 sec)
# INFO:tensorflow:global_step/sec: 1.53779
# INFO:tensorflow:loss = 0.014730988, step = 36200 (65.894 sec)
# INFO:tensorflow:global_step/sec: 1.51469
# INFO:tensorflow:loss = 0.015479689, step = 36300 (65.154 sec)
# INFO:tensorflow:global_step/sec: 1.53597
# INFO:tensorflow:loss = 0.017693268, step = 36400 (65.967 sec)
# INFO:tensorflow:global_step/sec: 1.51515
# INFO:tensorflow:loss = 0.016492328, step = 36500 (65.138 sec)
# INFO:tensorflow:global_step/sec: 1.53485
# INFO:tensorflow:loss = 0.017424043, step = 36600 (65.952 sec)
# INFO:tensorflow:global_step/sec: 1.51929
# INFO:tensorflow:loss = 0.015187703, step = 36700 (65.022 sec)
# INFO:tensorflow:global_step/sec: 1.53468
# INFO:tensorflow:loss = 0.013756109, step = 36800 (66.013 sec)
# INFO:tensorflow:global_step/sec: 1.51436
# INFO:tensorflow:loss = 0.0134916445, step = 36900 (65.181 sec)
# INFO:tensorflow:Saving checkpoints for 37000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-21:34:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-37000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-21:35:19
# INFO:tensorflow:Saving dict for global step 37000: albedo_loss = 0.025600538, global_step = 37000, lighting_loss = 0.008463811, loss = 0.016732328, normal_loss = 0.045736548, reconstruction_loss = 0.023717638
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 37000: ./drive/Colab Notebooks/SFSNet/model.ckpt-37000
# INFO:tensorflow:global_step/sec: 0.74277
# INFO:tensorflow:loss = 0.014314106, step = 37000 (134.631 sec)
# INFO:tensorflow:global_step/sec: 1.53784
# INFO:tensorflow:loss = 0.013469305, step = 37100 (65.026 sec)
# INFO:tensorflow:global_step/sec: 1.53433
# INFO:tensorflow:loss = 0.014043808, step = 37200 (65.977 sec)
# INFO:tensorflow:global_step/sec: 1.51526
# INFO:tensorflow:loss = 0.01542793, step = 37300 (65.193 sec)
# INFO:tensorflow:global_step/sec: 1.53584
# INFO:tensorflow:loss = 0.014470975, step = 37400 (65.965 sec)
# INFO:tensorflow:global_step/sec: 1.51604
# INFO:tensorflow:loss = 0.016477097, step = 37500 (65.107 sec)
# INFO:tensorflow:global_step/sec: 1.53663
# INFO:tensorflow:loss = 0.014349405, step = 37600 (65.987 sec)
# INFO:tensorflow:global_step/sec: 1.51448
# INFO:tensorflow:loss = 0.01481341, step = 37700 (65.119 sec)
# INFO:tensorflow:global_step/sec: 1.53502
# INFO:tensorflow:loss = 0.014240584, step = 37800 (66.056 sec)
# INFO:tensorflow:global_step/sec: 1.51231
# INFO:tensorflow:loss = 0.013614658, step = 37900 (65.213 sec)
# INFO:tensorflow:Saving checkpoints for 38000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-21:46:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-38000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-21:47:23
# INFO:tensorflow:Saving dict for global step 38000: albedo_loss = 0.02616635, global_step = 38000, lighting_loss = 0.00832552, loss = 0.016003476, normal_loss = 0.0457632, reconstruction_loss = 0.020369405
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 38000: ./drive/Colab Notebooks/SFSNet/model.ckpt-38000
# INFO:tensorflow:global_step/sec: 0.741345
# INFO:tensorflow:loss = 0.015813926, step = 38000 (134.890 sec)
# INFO:tensorflow:global_step/sec: 1.53506
# INFO:tensorflow:loss = 0.015345565, step = 38100 (65.144 sec)
# INFO:tensorflow:global_step/sec: 1.53442
# INFO:tensorflow:loss = 0.016245365, step = 38200 (66.021 sec)
# INFO:tensorflow:global_step/sec: 1.51617
# INFO:tensorflow:loss = 0.017112896, step = 38300 (65.106 sec)
# INFO:tensorflow:global_step/sec: 1.53551
# INFO:tensorflow:loss = 0.015628226, step = 38400 (65.970 sec)
# INFO:tensorflow:global_step/sec: 1.51383
# INFO:tensorflow:loss = 0.014322094, step = 38500 (65.212 sec)
# INFO:tensorflow:global_step/sec: 1.53415
# INFO:tensorflow:loss = 0.01446954, step = 38600 (66.039 sec)
# INFO:tensorflow:global_step/sec: 1.51316
# INFO:tensorflow:loss = 0.013830788, step = 38700 (65.231 sec)
# INFO:tensorflow:global_step/sec: 1.5353
# INFO:tensorflow:loss = 0.017119765, step = 38800 (66.616 sec)
# INFO:tensorflow:global_step/sec: 1.50397
# INFO:tensorflow:loss = 0.013251804, step = 38900 (65.008 sec)
# INFO:tensorflow:Saving checkpoints for 39000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-21:59:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-39000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-21:59:28
# INFO:tensorflow:Saving dict for global step 39000: albedo_loss = 0.0256807, global_step = 39000, lighting_loss = 0.008474658, loss = 0.01620504, normal_loss = 0.044853117, reconstruction_loss = 0.021694213
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 39000: ./drive/Colab Notebooks/SFSNet/model.ckpt-39000
# INFO:tensorflow:global_step/sec: 0.741787
# INFO:tensorflow:loss = 0.014733832, step = 39000 (134.810 sec)
# INFO:tensorflow:global_step/sec: 1.53444
# INFO:tensorflow:loss = 0.013085045, step = 39100 (65.170 sec)
# INFO:tensorflow:global_step/sec: 1.53767
# INFO:tensorflow:loss = 0.013241739, step = 39200 (65.962 sec)
# INFO:tensorflow:global_step/sec: 1.51546
# INFO:tensorflow:loss = 0.015114713, step = 39300 (65.058 sec)
# INFO:tensorflow:global_step/sec: 1.53628
# INFO:tensorflow:loss = 0.014588353, step = 39400 (66.008 sec)
# INFO:tensorflow:global_step/sec: 1.51407
# INFO:tensorflow:loss = 0.015341436, step = 39500 (65.131 sec)
# INFO:tensorflow:global_step/sec: 1.53775
# INFO:tensorflow:loss = 0.015706262, step = 39600 (65.832 sec)
# INFO:tensorflow:global_step/sec: 1.51887
# INFO:tensorflow:loss = 0.014291154, step = 39700 (65.036 sec)
# INFO:tensorflow:global_step/sec: 1.53666
# INFO:tensorflow:loss = 0.015804997, step = 39800 (65.933 sec)
# INFO:tensorflow:global_step/sec: 1.51667
# INFO:tensorflow:loss = 0.014363174, step = 39900 (65.078 sec)
# INFO:tensorflow:Saving checkpoints for 40000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-22:11:12
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-40000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-22:11:37
# INFO:tensorflow:Saving dict for global step 40000: albedo_loss = 0.025427109, global_step = 40000, lighting_loss = 0.0074136807, loss = 0.015471193, normal_loss = 0.04476738, reconstruction_loss = 0.020090504
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 40000: ./drive/Colab Notebooks/SFSNet/model.ckpt-40000
# INFO:tensorflow:global_step/sec: 0.71751
# INFO:tensorflow:loss = 0.01461619, step = 40000 (139.372 sec)
# INFO:tensorflow:global_step/sec: 1.53979
# INFO:tensorflow:loss = 0.013490527, step = 40100 (64.943 sec)
# INFO:tensorflow:global_step/sec: 1.53557
# INFO:tensorflow:loss = 0.014686756, step = 40200 (65.922 sec)
# INFO:tensorflow:global_step/sec: 1.51738
# INFO:tensorflow:loss = 0.013459998, step = 40300 (65.104 sec)
# INFO:tensorflow:global_step/sec: 1.53463
# INFO:tensorflow:loss = 0.014959058, step = 40400 (66.012 sec)
# INFO:tensorflow:global_step/sec: 1.51516
# INFO:tensorflow:loss = 0.015318281, step = 40500 (65.150 sec)
# INFO:tensorflow:global_step/sec: 1.5365
# INFO:tensorflow:loss = 0.015342304, step = 40600 (65.977 sec)
# INFO:tensorflow:global_step/sec: 1.51463
# INFO:tensorflow:loss = 0.015335444, step = 40700 (65.129 sec)
# INFO:tensorflow:global_step/sec: 1.5354
# INFO:tensorflow:loss = 0.015124012, step = 40800 (65.984 sec)
# INFO:tensorflow:global_step/sec: 1.51359
# INFO:tensorflow:loss = 0.014617514, step = 40900 (65.213 sec)
# INFO:tensorflow:Saving checkpoints for 41000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-22:23:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-41000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-22:23:49
# INFO:tensorflow:Saving dict for global step 41000: albedo_loss = 0.02529633, global_step = 41000, lighting_loss = 0.008145937, loss = 0.015611711, normal_loss = 0.044556905, reconstruction_loss = 0.020093184
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 41000: ./drive/Colab Notebooks/SFSNet/model.ckpt-41000
# INFO:tensorflow:global_step/sec: 0.69995
# INFO:tensorflow:loss = 0.015430884, step = 41000 (142.868 sec)
# INFO:tensorflow:global_step/sec: 1.53638
# INFO:tensorflow:loss = 0.015266765, step = 41100 (65.088 sec)
# INFO:tensorflow:global_step/sec: 1.53559
# INFO:tensorflow:loss = 0.014509303, step = 41200 (65.955 sec)
# INFO:tensorflow:global_step/sec: 1.51408
# INFO:tensorflow:loss = 0.017557885, step = 41300 (65.214 sec)
# INFO:tensorflow:global_step/sec: 1.53782
# INFO:tensorflow:loss = 0.014486876, step = 41400 (65.844 sec)
# INFO:tensorflow:global_step/sec: 1.51692
# INFO:tensorflow:loss = 0.013526511, step = 41500 (65.107 sec)
# INFO:tensorflow:global_step/sec: 1.53673
# INFO:tensorflow:loss = 0.015423765, step = 41600 (65.893 sec)
# INFO:tensorflow:global_step/sec: 1.51591
# INFO:tensorflow:loss = 0.013616411, step = 41700 (65.146 sec)
# INFO:tensorflow:global_step/sec: 1.53435
# INFO:tensorflow:loss = 0.0128954165, step = 41800 (66.015 sec)
# INFO:tensorflow:global_step/sec: 1.51588
# INFO:tensorflow:loss = 0.013433501, step = 41900 (65.127 sec)
# INFO:tensorflow:Saving checkpoints for 42000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-22:35:30
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-42000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-22:35:58
# INFO:tensorflow:Saving dict for global step 42000: albedo_loss = 0.02549834, global_step = 42000, lighting_loss = 0.0075650765, loss = 0.01546253, normal_loss = 0.044268712, reconstruction_loss = 0.019932989
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 42000: ./drive/Colab Notebooks/SFSNet/model.ckpt-42000
# INFO:tensorflow:global_step/sec: 0.715025
# INFO:tensorflow:loss = 0.013968507, step = 42000 (139.855 sec)
# INFO:tensorflow:global_step/sec: 1.53636
# INFO:tensorflow:loss = 0.013315599, step = 42100 (65.089 sec)
# INFO:tensorflow:global_step/sec: 1.53883
# INFO:tensorflow:loss = 0.014962528, step = 42200 (65.975 sec)
# INFO:tensorflow:global_step/sec: 1.51206
# INFO:tensorflow:loss = 0.01675174, step = 42300 (65.145 sec)
# INFO:tensorflow:global_step/sec: 1.53697
# INFO:tensorflow:loss = 0.015225438, step = 42400 (65.906 sec)
# INFO:tensorflow:global_step/sec: 1.51706
# INFO:tensorflow:loss = 0.012908806, step = 42500 (65.074 sec)
# INFO:tensorflow:global_step/sec: 1.53606
# INFO:tensorflow:loss = 0.011300727, step = 42600 (65.927 sec)
# INFO:tensorflow:global_step/sec: 1.51798
# INFO:tensorflow:loss = 0.014767516, step = 42700 (65.054 sec)
# INFO:tensorflow:global_step/sec: 1.53569
# INFO:tensorflow:loss = 0.015879942, step = 42800 (65.940 sec)
# INFO:tensorflow:global_step/sec: 1.51777
# INFO:tensorflow:loss = 0.016911881, step = 42900 (65.061 sec)
# INFO:tensorflow:Saving checkpoints for 43000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-22:47:39
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-43000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-22:48:07
# INFO:tensorflow:Saving dict for global step 43000: albedo_loss = 0.025282623, global_step = 43000, lighting_loss = 0.008223279, loss = 0.015939483, normal_loss = 0.04463329, reconstruction_loss = 0.02132536
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 43000: ./drive/Colab Notebooks/SFSNet/model.ckpt-43000
# INFO:tensorflow:global_step/sec: 0.714488
# INFO:tensorflow:loss = 0.017903158, step = 43000 (139.960 sec)
# INFO:tensorflow:global_step/sec: 1.53758
# INFO:tensorflow:loss = 0.015959196, step = 43100 (65.037 sec)
# INFO:tensorflow:global_step/sec: 1.53688
# INFO:tensorflow:loss = 0.017451828, step = 43200 (65.898 sec)
# INFO:tensorflow:global_step/sec: 1.51709
# INFO:tensorflow:loss = 0.014880817, step = 43300 (65.084 sec)
# INFO:tensorflow:global_step/sec: 1.53813
# INFO:tensorflow:loss = 0.012515491, step = 43400 (65.865 sec)
# INFO:tensorflow:global_step/sec: 1.51928
# INFO:tensorflow:loss = 0.01558136, step = 43500 (64.970 sec)
# INFO:tensorflow:global_step/sec: 1.53675
# INFO:tensorflow:loss = 0.013907306, step = 43600 (65.896 sec)
# INFO:tensorflow:global_step/sec: 1.51837
# INFO:tensorflow:loss = 0.01706811, step = 43700 (65.037 sec)
# INFO:tensorflow:global_step/sec: 1.53773
# INFO:tensorflow:loss = 0.013330844, step = 43800 (65.886 sec)
# INFO:tensorflow:global_step/sec: 1.51679
# INFO:tensorflow:loss = 0.013809916, step = 43900 (65.073 sec)
# INFO:tensorflow:Saving checkpoints for 44000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-22:59:47
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-44000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-23:00:16
# INFO:tensorflow:Saving dict for global step 44000: albedo_loss = 0.025179628, global_step = 44000, lighting_loss = 0.007880073, loss = 0.015547281, normal_loss = 0.044162225, reconstruction_loss = 0.02029699
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 44000: ./drive/Colab Notebooks/SFSNet/model.ckpt-44000
# INFO:tensorflow:global_step/sec: 0.712566
# INFO:tensorflow:loss = 0.015400341, step = 44000 (140.338 sec)
# INFO:tensorflow:global_step/sec: 1.53766
# INFO:tensorflow:loss = 0.013953724, step = 44100 (65.034 sec)
# INFO:tensorflow:global_step/sec: 1.53834
# INFO:tensorflow:loss = 0.013258303, step = 44200 (66.040 sec)
# INFO:tensorflow:global_step/sec: 1.51343
# INFO:tensorflow:loss = 0.010932793, step = 44300 (65.041 sec)
# INFO:tensorflow:global_step/sec: 1.53909
# INFO:tensorflow:loss = 0.015028292, step = 44400 (65.843 sec)
# INFO:tensorflow:global_step/sec: 1.51679
# INFO:tensorflow:loss = 0.012479944, step = 44500 (65.058 sec)
# INFO:tensorflow:global_step/sec: 1.53712
# INFO:tensorflow:loss = 0.016080648, step = 44600 (65.842 sec)
# INFO:tensorflow:global_step/sec: 1.51994
# INFO:tensorflow:loss = 0.014735912, step = 44700 (65.008 sec)
# INFO:tensorflow:global_step/sec: 1.53847
# INFO:tensorflow:loss = 0.016845759, step = 44800 (65.945 sec)
# INFO:tensorflow:global_step/sec: 1.51341
# INFO:tensorflow:loss = 0.016403979, step = 44900 (65.131 sec)
# INFO:tensorflow:Saving checkpoints for 45000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-23:11:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-45000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-23:12:27
# INFO:tensorflow:Saving dict for global step 45000: albedo_loss = 0.025512308, global_step = 45000, lighting_loss = 0.008197387, loss = 0.016206458, normal_loss = 0.044735942, reconstruction_loss = 0.022168959
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 45000: ./drive/Colab Notebooks/SFSNet/model.ckpt-45000
# INFO:tensorflow:global_step/sec: 0.705336
# INFO:tensorflow:loss = 0.017699167, step = 45000 (141.777 sec)
# INFO:tensorflow:global_step/sec: 1.53801
# INFO:tensorflow:loss = 0.017067114, step = 45100 (65.018 sec)
# INFO:tensorflow:global_step/sec: 1.5376
# INFO:tensorflow:loss = 0.013779327, step = 45200 (65.960 sec)
# INFO:tensorflow:global_step/sec: 1.51606
# INFO:tensorflow:loss = 0.020649247, step = 45300 (65.037 sec)
# INFO:tensorflow:global_step/sec: 1.53568
# INFO:tensorflow:loss = 0.012710099, step = 45400 (65.982 sec)
# INFO:tensorflow:global_step/sec: 1.51706
# INFO:tensorflow:loss = 0.017538816, step = 45500 (65.052 sec)
# INFO:tensorflow:global_step/sec: 1.5374
# INFO:tensorflow:loss = 0.0146086095, step = 45600 (65.918 sec)
# INFO:tensorflow:global_step/sec: 1.51858
# INFO:tensorflow:loss = 0.014595982, step = 45700 (64.978 sec)
# INFO:tensorflow:global_step/sec: 1.53789
# INFO:tensorflow:loss = 0.01539678, step = 45800 (65.024 sec)
# INFO:tensorflow:global_step/sec: 1.52859
# INFO:tensorflow:loss = 0.012306134, step = 45900 (65.420 sec)
# INFO:tensorflow:Saving checkpoints for 46000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-23:24:08
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-46000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-23:24:36
# INFO:tensorflow:Saving dict for global step 46000: albedo_loss = 0.02498215, global_step = 46000, lighting_loss = 0.006796053, loss = 0.014944004, normal_loss = 0.042645823, reconstruction_loss = 0.019468637
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 46000: ./drive/Colab Notebooks/SFSNet/model.ckpt-46000
# INFO:tensorflow:global_step/sec: 0.712026
# INFO:tensorflow:loss = 0.012870771, step = 46000 (140.444 sec)
# INFO:tensorflow:global_step/sec: 1.53689
# INFO:tensorflow:loss = 0.016426072, step = 46100 (65.067 sec)
# INFO:tensorflow:global_step/sec: 1.53484
# INFO:tensorflow:loss = 0.0153988935, step = 46200 (65.956 sec)
# INFO:tensorflow:global_step/sec: 1.51606
# INFO:tensorflow:loss = 0.015139221, step = 46300 (65.157 sec)
# INFO:tensorflow:global_step/sec: 1.53353
# INFO:tensorflow:loss = 0.0136795845, step = 46400 (66.103 sec)
# INFO:tensorflow:global_step/sec: 1.51684
# INFO:tensorflow:loss = 0.0143665355, step = 46500 (65.032 sec)
# INFO:tensorflow:global_step/sec: 1.5361
# INFO:tensorflow:loss = 0.0143350465, step = 46600 (65.914 sec)
# INFO:tensorflow:global_step/sec: 1.51592
# INFO:tensorflow:loss = 0.01403692, step = 46700 (65.152 sec)
# INFO:tensorflow:global_step/sec: 1.5381
# INFO:tensorflow:loss = 0.013284555, step = 46800 (65.796 sec)
# INFO:tensorflow:global_step/sec: 1.51955
# INFO:tensorflow:loss = 0.014783137, step = 46900 (65.032 sec)
# INFO:tensorflow:Saving checkpoints for 47000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-23:36:17
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-47000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-23:36:46
# INFO:tensorflow:Saving dict for global step 47000: albedo_loss = 0.025048334, global_step = 47000, lighting_loss = 0.007792044, loss = 0.015356101, normal_loss = 0.042466655, reconstruction_loss = 0.020090703
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 47000: ./drive/Colab Notebooks/SFSNet/model.ckpt-47000
# INFO:tensorflow:global_step/sec: 0.708215
# INFO:tensorflow:loss = 0.014813763, step = 47000 (141.197 sec)
# INFO:tensorflow:global_step/sec: 1.53639
# INFO:tensorflow:loss = 0.013151953, step = 47100 (65.087 sec)
# INFO:tensorflow:global_step/sec: 1.53653
# INFO:tensorflow:loss = 0.012904607, step = 47200 (65.899 sec)
# INFO:tensorflow:global_step/sec: 1.51931
# INFO:tensorflow:loss = 0.016772818, step = 47300 (65.003 sec)
# INFO:tensorflow:global_step/sec: 1.5394
# INFO:tensorflow:loss = 0.011980207, step = 47400 (65.801 sec)
# INFO:tensorflow:global_step/sec: 1.51675
# INFO:tensorflow:loss = 0.015456757, step = 47500 (65.090 sec)
# INFO:tensorflow:global_step/sec: 1.54033
# INFO:tensorflow:loss = 0.014445904, step = 47600 (65.773 sec)
# INFO:tensorflow:global_step/sec: 1.51871
# INFO:tensorflow:loss = 0.013843428, step = 47700 (64.994 sec)
# INFO:tensorflow:global_step/sec: 1.53854
# INFO:tensorflow:loss = 0.01472385, step = 47800 (65.917 sec)
# INFO:tensorflow:global_step/sec: 1.51719
# INFO:tensorflow:loss = 0.014527044, step = 47900 (64.991 sec)
# INFO:tensorflow:Saving checkpoints for 48000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-03-23:48:30
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-48000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-03-23:48:57
# INFO:tensorflow:Saving dict for global step 48000: albedo_loss = 0.024858413, global_step = 48000, lighting_loss = 0.007357699, loss = 0.0150595475, normal_loss = 0.0421423, reconstruction_loss = 0.019593613
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 48000: ./drive/Colab Notebooks/SFSNet/model.ckpt-48000
# INFO:tensorflow:global_step/sec: 0.703773
# INFO:tensorflow:loss = 0.013025416, step = 48000 (142.094 sec)
# INFO:tensorflow:global_step/sec: 1.53993
# INFO:tensorflow:loss = 0.015735328, step = 48100 (64.942 sec)
# INFO:tensorflow:global_step/sec: 1.5401
# INFO:tensorflow:loss = 0.015916789, step = 48200 (65.731 sec)
# INFO:tensorflow:global_step/sec: 1.51787
# INFO:tensorflow:loss = 0.012496161, step = 48300 (65.075 sec)
# INFO:tensorflow:global_step/sec: 1.53816
# INFO:tensorflow:loss = 0.012945987, step = 48400 (65.947 sec)
# INFO:tensorflow:global_step/sec: 1.51502
# INFO:tensorflow:loss = 0.014110336, step = 48500 (65.071 sec)
# INFO:tensorflow:global_step/sec: 1.53796
# INFO:tensorflow:loss = 0.012401623, step = 48600 (65.021 sec)
# INFO:tensorflow:global_step/sec: 1.51106
# INFO:tensorflow:loss = 0.014763689, step = 48700 (66.179 sec)
# INFO:tensorflow:global_step/sec: 1.53556
# INFO:tensorflow:loss = 0.015129466, step = 48800 (65.952 sec)
# INFO:tensorflow:global_step/sec: 1.51669
# INFO:tensorflow:loss = 0.0133962175, step = 48900 (65.105 sec)
# INFO:tensorflow:Saving checkpoints for 49000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-04-00:00:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-49000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-04-00:01:05
# INFO:tensorflow:Saving dict for global step 49000: albedo_loss = 0.024719475, global_step = 49000, lighting_loss = 0.0069422433, loss = 0.014654799, normal_loss = 0.04150955, reconstruction_loss = 0.018655572
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 49000: ./drive/Colab Notebooks/SFSNet/model.ckpt-49000
# INFO:tensorflow:global_step/sec: 0.722228
# INFO:tensorflow:loss = 0.014443769, step = 49000 (138.460 sec)
# INFO:tensorflow:global_step/sec: 1.5359
# INFO:tensorflow:loss = 0.0150109595, step = 49100 (65.109 sec)
# INFO:tensorflow:global_step/sec: 1.53444
# INFO:tensorflow:loss = 0.013614595, step = 49200 (66.187 sec)
# INFO:tensorflow:global_step/sec: 1.51134
# INFO:tensorflow:loss = 0.013625323, step = 49300 (65.150 sec)
# INFO:tensorflow:global_step/sec: 1.53711
# INFO:tensorflow:loss = 0.013541595, step = 49400 (65.931 sec)
# INFO:tensorflow:global_step/sec: 1.51882
# INFO:tensorflow:loss = 0.012284481, step = 49500 (64.966 sec)
# INFO:tensorflow:global_step/sec: 1.53786
# INFO:tensorflow:loss = 0.01507343, step = 49600 (65.899 sec)
# INFO:tensorflow:global_step/sec: 1.51575
# INFO:tensorflow:loss = 0.017544663, step = 49700 (65.100 sec)
# INFO:tensorflow:global_step/sec: 1.53713
# INFO:tensorflow:loss = 0.015296382, step = 49800 (65.858 sec)
# INFO:tensorflow:global_step/sec: 1.51817
# INFO:tensorflow:loss = 0.011916426, step = 49900 (65.068 sec)
# INFO:tensorflow:Saving checkpoints for 50000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-04-00:12:47
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-50000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-04-00:13:15
# INFO:tensorflow:Saving dict for global step 50000: albedo_loss = 0.024709776, global_step = 50000, lighting_loss = 0.007053349, loss = 0.014884858, normal_loss = 0.041959878, reconstruction_loss = 0.019384326
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 50000: ./drive/Colab Notebooks/SFSNet/model.ckpt-50000
# INFO:tensorflow:global_step/sec: 0.709698
# INFO:tensorflow:loss = 0.013460988, step = 50000 (140.906 sec)
# INFO:tensorflow:global_step/sec: 1.53432
# INFO:tensorflow:loss = 0.014450076, step = 50100 (65.175 sec)
# INFO:tensorflow:global_step/sec: 1.53468
# INFO:tensorflow:loss = 0.014798522, step = 50200 (66.114 sec)
# INFO:tensorflow:global_step/sec: 1.51432
# INFO:tensorflow:loss = 0.012932215, step = 50300 (65.082 sec)
# INFO:tensorflow:global_step/sec: 1.53512
# INFO:tensorflow:loss = 0.013468376, step = 50400 (65.964 sec)
# INFO:tensorflow:global_step/sec: 1.51708
# INFO:tensorflow:loss = 0.0124785565, step = 50500 (65.094 sec)
# INFO:tensorflow:global_step/sec: 1.5337
# INFO:tensorflow:loss = 0.012624095, step = 50600 (66.006 sec)
# INFO:tensorflow:global_step/sec: 1.51627
# INFO:tensorflow:loss = 0.012265578, step = 50700 (65.147 sec)
# INFO:tensorflow:global_step/sec: 1.5371
# INFO:tensorflow:loss = 0.011673628, step = 50800 (66.093 sec)
# INFO:tensorflow:global_step/sec: 1.51176
# INFO:tensorflow:loss = 0.014532255, step = 50900 (65.112 sec)
# INFO:tensorflow:Saving checkpoints for 51000 into ./drive/Colab Notebooks/SFSNet/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-04-00:24:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-51000
# INFO:tensorflow:Loss for final step: 0.015116063.
# ({'albedo_loss': 0.024709776,
#   'global_step': 50000,
#   'lighting_loss': 0.007053349,
#   'loss': 0.014884858,
#   'normal_loss': 0.041959878,
#   'reconstruction_loss': 0.019384326},
#  [])

# %% [markdown]
# ## Please ignore below

# %% [markdown]
#  Inference at 30k steps

# %%
predict_input_fn = tf.estimator.inputs.numpy_input_fn(
  x=input_fn(test_data)[0],
  batch_size=10,
  num_epochs=1,
  shuffle=False)

# %%
predictions = list(estimator.predict(input_fn=predict_input_fn))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-30000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
test_image = test_data["images"][10]
predicted_normal = np.clip(predictions[10]["normal"], 0, 1)
predicted_albedo = np.clip(predictions[10]["albedo"], 0, 1)
predicted_recon = np.clip(predictions[10]["recon"], 0, 1)
predicted_shading = np.clip(predictions[10]["shading"], 0, 1)

# %%
from matplotlib import pyplot as plt
fig, axs = plt.subplots(1,5,figsize=(20, 4))

img = test_image
axs[0].imshow(img)
axs[0].axis('off')
axs[0].set_title('Image')

img = predicted_albedo
axs[1].imshow(img)
axs[1].axis('off')
axs[1].set_title('Albedo')

img = predicted_normal
axs[2].imshow(img)
axs[2].axis('off')
axs[2].set_title('normal')

img = predicted_shading
axs[3].imshow(img)
axs[3].axis('off')
axs[3].set_title('shading')

img = predicted_recon
axs[4].imshow(img)
axs[4].axis('off')
axs[4].set_title('recon')
# Out:
# Text(0.5,1,'recon')

# %%
img = predicted_recon
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
from google.colab import files
files.upload()
#!ls
# Out:
#      <input type="file" id="files-3d8dbac8-fc10-493f-87de-2fef9b4a2c52" name="files[]" multiple disabled />
#      <output id="result-3d8dbac8-fc10-493f-87de-2fef9b4a2c52">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mask.jpg to mask.jpg
# Saving inp.jpg to inp.jpg
# {'inp.jpg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x00\xda\x00\xb2\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xf0\x1aZ\n0\xea\xa6\x8c\x1fJwCi\x8d=h\x1d)qI\xda\x93\x10\xa2\x9dM\x14\xea\x07\x1d\xc3\xbd\x02\x8a\x05\x1d\r:\x8b\xfcC\xebJ:g\xd8\xd2\x0f\xbc(\x1ft\xff\x00\xbbR\x88\x96\xe2/J\x07Q\xf5\xa0}\xda\x07Q\xf8\xd0Dw\x11\xba\xd2R\xb7\xde4\x9d\xa9\x9a\n(\xa0QLb7J^\xff\x00\x85#v\xa3\xb9\xa1\x10\xf7\x13\xbd>\x9a:\xd3\xa8)\x08i\xa6\x9ci\xa6\x86\x0c(\xa2\x8aB;\xf3\xb5\xba\xa8?QM\xf2\xad\xdb\xefA\x11\xfa\xa8\xads\xa3\xd9H\x07\x91\xae\xe9\xcd\xfe\xfb\x14\xfet\x8d\xa0\xce>\xe5\xcd\x9c\xc3\xd6)\xd4\xd7\x9f\xefw=\xeb\xc1\x99\x1fa\xb1~\xb6\xb1~\n\x05\'\xf6N\x98\xfdmW\xf0$V\xaf\xf6&\xa0>\xed\xbbI\xfe\xe0\xcdD\xda]\xec|\xbd\xa5\xc2\xfdb4sIu\x1f-7\xd8\xccm\x03Ka\xfe\xa5\x97\xe8\xc6\xa2o\x0ei\xe7\xee\x99G\xfc\x0b\xff\x00\xadZm\x14\x91\xfd\xe4u\xfa\x8cTY8\xe3\x91\xf5\xabS\x97r]\x1aO\xa22\x1f\xc3v\xb9\xf9g\x90}qQ\xff\x00\xc22\x87\xee\xdd\x11\xf5O\xfe\xbdk\xb1ozU$v5j\xa4\x8c\x9e\x1e\x91\x8b\xff\x00\x08\xb4\xa4\xfc\xb7)\xf8\xadtzG\xc1\xed\x7f\\\xd3\x16\xfa\xca\xefO\xf2\xdc\x95\x0b+\xba\x9e?\xe0&\x98\xaeTd\xf1^\xf7\xe08>\xcf\xe1\x1d9[\x01\xa4F|\x1e\xbc\xb1\xc5i\t\xdfs\x93\x15F\x9c\x15\xe2x\\\xdf\x03\xfcg\x10\xf9!\xb1\x94\x7f\xb1r?\xa8\x15\xcdj>\x06\xf1\x06\x953Gud\x15\x97 \xed\x95[\xf9\x1a\xfa\xc6\xfbV\xb2\xb2R\xb3\xcc\xa1\xfb 9\'\xfc+\xce5+(\xf5\x8b\xb7\x99\xe5*\xa5\xd9\x80\xcf8\xa2uTNz4\x94\x9e\xa7\x81\xbe\x81\xa9\xa9$\xd9\xc9\xf8\x0c\xd4O\xa4\xdf\xa0\xf9\xac\xe7\x1f\xf6\xcc\xff\x00\x85}\x07o\xe1\xcd8.H\xdd\xf5\xab#\xc3\xdaq\x18\xf2\x96\xb3X\x83\xa3\xea\xf0\xee|\xda\xd6\x97\t\xf7\xa0\x91~\xaaj3\x1b\x0e\xa2\xbe\x91\x93\xc2\x96\x92cj\xb0\'\xd0\xd5\x1b\xbf\x01]\x95/m\xb6a\xfd\xc6\x1c\xd5\xacE\xfa\x0b\xea\xf1\xee|\xf2A\xc8\xe2\x8e\xe6\xbd\x82\xf3C\xfb,\xa6;\xbd=\x15\x87P\xf1\x83Y\xb2\xe9\x1ay?5\x85\xbf=0\x80S\xf6\xe9\x0f\xeaR{3\xcc\x00\xe6\x9d^\x8at--\xce\r\x9a~\x04\x8a\x81\xbc7\xa51\xc0\x81\x97\xe9!\xa6\xab\xc4o\x03Q\x1c\x01\xa6\x9a\xef\x1f\xc2zst3/\xd1\x85W\x7f\x07\xda\x7f\r\xc4\xc3\xea\x01\xa7\xedbg,%^\xc7\x19Eu\xff\x00\xf0\x86\xc5\xff\x00?M\xff\x00|\xd1O\xda\xc4_U\xab\xd8\xd6\xf2"o\xe1\x14-\xb2\x0e\x99\x1fCM\x05\x87z\x91X\xd7\x15\xcfo\x96\x0f\xa0\xa9\x0c\x8as\x1d\xc4\xa8\x7f\xd9sV\xa3\xbc\xd5\xa1\xe2=N\xe0\x0e\xdf6\x7f\x9d@\xa4w\xcdI\x92}i]\x8 ...
#  'mask.jpg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xc0\x00\x0b\x08\x02d\x01\xf4\x01\x01\x11\x00\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfe\x7f\xe8\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a(\xa2\x8a( ...

# %%
#import scipy.misc as im

input = []
mask1 = []

#inp = im.imread('inp.jpg')
im=io.imread('inp.jpg')
input.append(skimage.transform.resize(im,(128,128))) 
input.append(skimage.transform.resize(im,(128,128)))
input.append(skimage.transform.resize(im,(128,128)))
input.append(skimage.transform.resize(im,(128,128)))
input.append(skimage.transform.resize(im,(128,128)))
input.append(skimage.transform.resize(im,(128,128)))
input.append(skimage.transform.resize(im,(128,128)))
input.append(skimage.transform.resize(im,(128,128)))
input.append(skimage.transform.resize(im,(128,128)))
input.append(skimage.transform.resize(im,(128,128)))
input = np.asarray(input).astype(np.float32)
#input.append(np.array(inp))
#input.append(np.array(inp))
#input = np.array(input)

mk=io.imread('mask.jpg')

mask1.append(skimage.transform.resize(mk,(128,128))) 
mask1.append(skimage.transform.resize(mk,(128,128)))
mask1.append(skimage.transform.resize(mk,(128,128)))
mask1.append(skimage.transform.resize(mk,(128,128)))
mask1.append(skimage.transform.resize(mk,(128,128)))
mask1.append(skimage.transform.resize(mk,(128,128)))
mask1.append(skimage.transform.resize(mk,(128,128)))
mask1.append(skimage.transform.resize(mk,(128,128)))
mask1.append(skimage.transform.resize(mk,(128,128)))
mask1.append(skimage.transform.resize(mk,(128,128)))
mask1 = np.asarray(mask1).astype(np.float32)

mask1 = np.expand_dims(mask1, axis=3)
mask1 = np.repeat(mask1,3,axis=3)
print(mask1.shape)
# Out:
# (10, 128, 128, 3)
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
test_data = {"images":input, "mask": mask1, "normals": normal_list[test_min_index:2], "albedos": albedo_list[test_min_index:2],\
             "lightings": light[test_min_index:2], "nlabel": normal_label[test_min_index:2],\
             "alabel": albedo_label[test_min_index:2], "mlabel": mask_label[test_min_index:2]}

# %%
predict_input_fn = tf.estimator.inputs.numpy_input_fn(
  x=input_fn(test_data)[0],
  batch_size=10,
  num_epochs=1,
  shuffle=False)

# %%
predictions = list(estimator.predict(input_fn=predict_input_fn))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./drive/Colab Notebooks/SFSNet/model.ckpt-30000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
test_image = test_data["images"][0]
predicted_normal = np.clip(predictions[0]["normal"], 0, 1)
predicted_albedo = np.clip(predictions[0]["albedo"], 0, 1)
predicted_recon = np.clip(predictions[0]["recon"], 0, 1)
predicted_shading = np.clip(predictions[0]["shading"], 0, 1)

# %%
from matplotlib import pyplot as plt
fig, axs = plt.subplots(1,5,figsize=(20, 4))

img = test_image
axs[0].imshow(img)
axs[0].axis('off')
axs[0].set_title('Image')

img = predicted_albedo
axs[1].imshow(img)
axs[1].axis('off')
axs[1].set_title('Albedo')

img = predicted_normal
axs[2].imshow(img)
axs[2].axis('off')
axs[2].set_title('normal')

img = predicted_shading
axs[3].imshow(img)
axs[3].axis('off')
axs[3].set_title('shading')

img = predicted_recon
axs[4].imshow(img)
axs[4].axis('off')
axs[4].set_title('recon')
# Out:
# Text(0.5,1,'recon')

# %%
image_t = np.array([image_list[0],image_list[1]])
normal_t = np.array([normal_list[0],normal_list[1]])
albedo_t =  np.array([albedo_list[0],albedo_list[1]])
light_t =  np.array([light[0],light[1]])
mask_t =  np.array([mask[0],mask[1]])

# %%
plt.imshow(normal_t[0])

# %%
def ShadingLayer(normal_output, light_output):
    sz=normal_output.shape
    pi = np.pi
    att = pi*np.array([1, 2.0/3, 0.25])
    c1=att[0]*(1.0/np.sqrt(4*pi))
    c2=att[1]*(np.sqrt(3.0/(4*pi)))
    c3=att[2]*0.5*(np.sqrt(5.0/(4*pi)))
    c4=att[2]*(3.0*(np.sqrt(5.0/(12*pi))))
    c5=att[2]*(3.0*(np.sqrt(5.0/(48*pi))))
    
    shading_img_batch = []  # Empty list for storing all the shading images of the batch
    
    for i in range(2):
        nx = normal_output[i,:,:,0]
        ny = normal_output[i,:,:,1]
        nz = normal_output[i,:,:,2]

        H1 = c1*np.ones((sz[1],sz[2]))
        H2 = c2*nz
        H3 = c2*nx
        H4 = c2*ny
        H5 = c3*(2*nz*nz - nx*nx -ny*ny)
        H6 = c4*nx*nz
        H7 = c4*ny*nz
        H8 = c5*(nx*nx - ny*ny)
        H9 = c4*nx*ny

        shading_img = []
        
        for j in range(0,3):
            L = light_output[i,j*9:(j+1)*9]
            shading_img.append(L[0]*H1+L[1]*H2+L[2]*H3+L[3]*H4+L[4]*H5+L[5]*H6+L[6]*H7+L[7]*H8+L[8]*H9)
            #print(np.array(shading_img).shape)
        #print(len(shading_img))
        shading_img = np.stack(shading_img, axis=0)
        #print(np.array(shading_img).shape)
        shading_img = np.rollaxis(shading_img,0,3)
        print(np.array(shading_img).shape)
        #print(shading_img.shape)
        shading_img_batch.append(shading_img)

    shading_img_batch = np.stack(shading_img_batch, axis=0)
    print(shading_img_batch.shape)
    

    return shading_img_batch

# %%
shade = ShadingLayer(normal_t,light_t)
plt.imshow(shade[1])
#print(shade[1].shape)
# Out:
# (128, 128, 3)
# (128, 128, 3)
# (2, 128, 128, 3)

# %%
def reconstruction(albedo,shading):
  return np.multiply(albedo,shading)

# %%
plt.imshow(reconstruction(albedo_t[0], shade[0]))
plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
def shading_layer(normal_output, light_output):
  normal_output = np.rollaxis(normal_output,3,1)
  sz=normal_output.shape

  att = np.pi*np.array([1, 2.0/3, 0.25])

  c1=att[0]*(1.0/np.sqrt(4*np.pi))
  c2=att[1]*(np.sqrt(3.0/(4*np.pi)))
  c3=att[2]*0.5*(np.sqrt(5.0/(4*np.pi)))
  c4=att[2]*(3.0*(np.sqrt(5.0/(12*np.pi))))
  c5=att[2]*(3.0*(np.sqrt(5.0/(48*np.pi))))
  
  shade = normal_output
  for i in range(0,sz[0]) :
    nx=normal_output[i,0,:,:]
    ny=normal_output[i,1,:,:]		
    nz=normal_output[i,2,:,:]	


    H1=c1*np.ones((sz[2],sz[3]))
    H2=c2*nz
    H3=c2*nx
    H4=c2*ny
    H5=c3*(2*nz*nz - nx*nx -ny*ny)
    H6=c4*nx*nz
    H7=c4*ny*nz
    H8=c5*(nx*nx - ny*ny)
    H9=c4*nx*ny	


    for j in range(0,3):
      L=light_output[i,j*9:(j+1)*9]
      shade[i,j,:,:]=L[0]*H1+L[1]*H2+L[2]*H3+L[3]*H4+L[4]*H5+L[5]*H6+L[6]*H7+L[7]*H8+L[8]*H9

  return np.rollaxis(shade, 1, 4)

# %%
shade = shading_layer(normal_t,light_t)
plt.imshow(shade[1])
# np.array(shade).shape

# %%
plt.imshow(shade[1])
plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
def reconstruction(albedo,shading):
  return np.multiply(albedo,shading)

# %%
plt.imshow(reconstruction(albedo_t[0], shade[0]))
plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
np.min(shade[0])
# Out:
# 0.10889147

# %%
np.max(shade[0])
# Out:
# 0.20796834

# %%
shade[1] = np.multiply((200/255),shade[1])

# %%
plt.imshow(shade[1])
plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)
